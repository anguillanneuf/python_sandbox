# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph(nx.path_graph(4))

# %%
pr = nx.pagerank(G, alpha = 0.9)

# %%
pr

# %%
G.adj?

# %%
print(nx.info(G))

# %%
print(nx.edges(G))

# %%
nx.draw_spring(G)
# nx.draw_networkx_labels(G,pos=nx.spring_layout(G))

# %%
pr_01 = nx.pagerank(G, personalization={0:1,1:1,2:1,3:1})
print(pr_01)
pr_02 = nx.pagerank(G, personalization={0:1,1:100,2:1,3:1})
print(pr_02)

# %%
help(nx.pagerank)

# %%
help(nx.pagerank_alg)

# %%
G.edge

# %%
pr_03 = nx.pagerank(G, personalization={0:1,1:1,2:1,3:1})
print(pr_03)

G.add_weighted_edges_from([(0,1,3.0),(1,2,7.5)])
# Edge data key to use as weight.  If None weights are set to 1.
pr_04 = nx.pagerank(G, personalization={0:1,1:1,2:1,3:1}) 
print(pr_04)

# %%
G.edge

# %%
1/(np.sqrt(2*np.pi*4))*np.exp(-0.5)

# %%
G = nx.DiGraph()
G.add_edges_from([('a','b',{'weight':10}),('a','c',{'weight':10}),('b','c',{'weight':10}),('c','a',{'weight':18})])
nx.pagerank(G, weight = 'weight')

# %%
G = nx.DiGraph()
G.add_edges_from([('a','b',{'weight':10}),('a','c',{'weight':8}),('b','c',{'weight':8}),('c','a',{'weight':18}),('a','d', {'weight':2}),('b', 'd', {'weight':2}),('d','c',{'weight':4})])
nx.pagerank(G, weight = 'weight')

# %%
G = nx.DiGraph()
G.add_edges_from([('a','b',{'weight':9}),('a','c',{'weight':8}),('b','c',{'weight':7}),('c','a',{'weight':17}),('a','d', {'weight':2}),('b', 'd', {'weight':2}),('d','c',{'weight':4})])
nx.pagerank(G, weight = 'weight')
